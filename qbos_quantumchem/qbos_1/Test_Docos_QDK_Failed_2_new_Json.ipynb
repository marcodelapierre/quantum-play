# %%
import qbos
tqb = qbos.core()
tqb.qb12()              # Set up meaningful defaults
tqb.acc   = 'qdk_gen1'  # If QDK is not available, use a simulator by setting: tqb.acc = 'aer'
tqb.sn    = 32          # 32 shots
tqb.qn    = 2           # 2 qubits
tqb.instring = '''
__qpu__ void QBCIRCUIT(qreg q){
OPENQASM 2.0;
include "qelib1.inc";
creg c[2];
h q[0];
x q[1];
measure q[1] -> c[1];
measure q[0] -> c[0];
}
'''
tqb.run()
# Out:
# :{lambda(pybind11::detail::function_call&)#3}::operator()(pybind11::detail::function_call) const+0xb5)
# 0x7faeb5d3edc9: (pybind11::cpp_function::initialize<pybind11::cpp_function::initialize<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}, void, qbOS::Qbqe*, pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(pybind11::cpp_function::initialize<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&&, void (*)(qbOS::Qbqe*), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(pybind11::detail::function_call&)#3}::_FUN(pybind11::detail::function_call)+0x21)
# 0x7faeb5ca88fb: (pybind11::cpp_function::dispatcher(_object*, _object*, _object*)+0xff3)
# 0x5f6929: (PyCFunction_Call+0x59)
# 0x5f74f6: (_PyObject_MakeTpCall+0x296)
# 0x50c383: (PyMethod_New+0xb73)
# 0x570b26: (_PyEval_EvalFrameDefault+0x5786)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x6902a7: (PyEval_EvalCode+0x27)
# 0x6023c4: (_PyBuiltin_Init+0x1034)
# 0x5c6730: (PyObject_RichCompareBool+0x790)
# 0x56bacd: (_PyEval_EvalFrameDefault+0x72d)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x505166: (PyDescr_NewMember+0x1c36)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bacd: (_PyEval_EvalFrameDefault+0x72d)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x5f6eb3: (_PyFunction_Vectorcall+0x393)
# 0x50bc2c: (PyMethod_New+0x41c)
# 0x5f6082: (PyObject_Call+0x62)
# 0x56d2d5: (_PyEval_EvalFrameDefault+0x1f35)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x50bca0: (PyMethod_New+0x490)
# 0x56cc1f: (_PyEval_EvalFrameDefault+0x187f)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x56d4d6: (_PyEval_EvalFrameDefault+0x2136)
# 0x501488: (PyGen_NewWithQualName+0x178)
# 0x7faed4203ef9: -- error: unable to obtain symbol name for this frame
# 0x7faed4205083: (PyInit__asyncio+0xea3)
# 0x5f74f6: (_PyObject_MakeTpCall+0x296)
# 0x600f63: (_PyContext_Init+0x173)
# 0x5c6617: (PyObject_RichCompareBool+0x677)
# 0x5f6648: (PyVectorcall_Call+0x58)
# 0x571cbb: (_PyEval_EvalFrameDefault+0x691b)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x5f6cd6: (_PyFunction_Vectorcall+0x1b6)
# 0x56bbfa: (_PyEval_EvalFrameDefault+0x85a)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x50bca0: (PyMethod_New+0x490)
# 0x570b26: (_PyEval_EvalFrameDefault+0x5786)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x6902a7: (PyEval_EvalCode+0x27)
# 0x6023c4: (_PyBuiltin_Init+0x1034)
# 0x5c6730: (PyObject_RichCompareBool+0x790)
# 0x56bacd: (_PyEval_EvalFrameDefault+0x72d)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x5f6eb3: (_PyFunction_Vectorcall+0x393)
# 0x56bacd: (_PyEval_EvalFrameDefault+0x72d)
# 0x569dba: (_PyEval_EvalCodeWithName+0x26a)
# 0x5f6eb3: (_PyFunction_Vectorcall+0x393)
# 0x5f6082: (PyObject_Call+0x62)
# 0x6b9a92: (PyBytes_FromString+0x1682)
# 0x6b9e99: (Py_RunMain+0x379)
# 0x6ba0bd: (Py_BytesMain+0x2d)
# 0x7faed4856083: (__libc_start_main+0xf3)
# 0x5fc5fe: (_start+0x2e)
# 0x7faecc0d6deb: (xacc::error(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::function<bool ()>)+0x2b)
# 0x7faecc0d1033: (xacc::RemoteAccelerator::handleExceptionRestClientPost(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::map<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, std::less<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > >, std::allocator<std::pair<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > > > >) [clone .cold]+0x267)
# 0x7faecc15967e: (xacc::RemoteAccelerator::execute(std::shared_ptr<xacc::AcceleratorBuffer>, std::shared_ptr<xacc::CompositeInstruction>)+0x2ae)
# 0x7faeb59679c4: (xacc::quantum::QuantumBrillianceRemoteAccelerator::execute(std::shared_ptr<xacc::AcceleratorBuffer>, std::vector<std::shared_ptr<xacc::CompositeInstruction>, std::allocator<std::shared_ptr<xacc::CompositeInstruction> > >)+0x2ac)
# 0x7faeb5bc0420: (qbOS::Qbqe::run(unsigned long const&, unsigned long const&)+0x72c2)
# 0x7faeb5bc5591: (qbOS::Qbqe::run()+0xbd1)
# 0x7faeb5d009d9: (pybind11::cpp_function::cpp_function<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}::operator()(qbOS::Qbqe*) const+0x65)
# 0x7faeb5ddc2eb: (void pybind11::detail::argument_loader<qbOS::Qbqe*>::call_impl<void, pybind11::cpp_function::cpp_function<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&, 0ul, pybind11::detail::void_type>(pybind11::cpp_function::cpp_function<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&, std::integer_sequence<unsigned long, 0ul>, pybind11::detail::void_type&&) &&+0x4b)
# 0x7faeb5d829a4: (std::enable_if<std::is_void<void>::value, pybind11::detail::void_type>::type pybind11::detail::argument_loader<qbOS::Qbqe*>::call<void, pybind11::detail::void_type, pybind11::cpp_function::cpp_function<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&>(pybind11::cpp_function::cpp_function<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&) &&+0x52)
# 0x7faeb5d3ed47: (pybind11::cpp_function::initialize<pybind11::cpp_function::initialize<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}, void, qbOS::Qbqe*, pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(pybind11::cpp_function::initialize<void, qbOS::Qbqe, , pybind11::name, pybind11::is_method, pybind11::sibling, char [59]>(void (qbOS::Qbqe::*)(), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(qbOS::Qbqe*)#1}&&, void (*)(qbOS::Qbqe*), pybind11::name const&, pybind11::is_method const&, pybind11::sibling const&, char const (&) [59])::{lambda(pybind11::detail::function_call&)#3}::operator()(pybind11::detail::functio
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 18>()
#       6 tqb.qn    = 2           # 2 qubits
#       7 tqb.instring = '''
#       8 __qpu__ void QBCIRCUIT(qreg q){
#       9 OPENQASM 2.0;
#    (...)
#      16 }
#      17 '''
# ---> 18 tqb.run()
#
# ValueError: The execution on hardware of your input circuit failed
